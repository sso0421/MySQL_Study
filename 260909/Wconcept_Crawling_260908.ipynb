# %%
from selenium import webdriver #webdriver가 사람 대신 크롤러의 역할을 함
from selenium.webdriver.chrome.service import Service #Service는 크롤러에게 로컬 컴퓨터 내 크롬브라우저 드라이브를 일치할 수 있게끔 해주며, 설치를 해 줌
from selenium.webdriver.chrome.options import Options #크롤러가 어떤 환경에서 어떤 방식으로 크롤링 하도록 할지 옵션을 설정
from webdriver_manager.chrome import ChromeDriverManager #실제 드라이브 설치 역할을 함
import time # 특정 사이트 접속 후, 스크립트 기반의 코드를 서버로부터 가져올 때까지 시간을 벌어주는 역할

service = Service(ChromeDriverManager().install()) #실행은 얘가 함
options = Options()

# options.add_argument("--headless") #가상브라우저를 현재 내 로컬컴퓨터에 나타나지 않도록 할 때
# options.add_argument("--disable-gpu") #가상브라우저를 사용하지 않기 때문에 굳이 gpu 메모리를 사용하지 않겠다는 의미
options.add_argument("--disable-dev-shm-usage") #큰 데이터의 크롤링 시, 데이터를 개발자도구 내 임시 메모리 공간을 사용하지 X (로컬의 공간을 바로 사용하겠다)
options.add_argument("--window-size=1920, 1080") #크롤러의 웹 브라우저 사이즈를 세팅
options.add_argument("--start-maximized") #주변 환경요소와 무관하게 브라우저 사이즈를 무조건 크게
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/152.0.0.0 Safari/537.36") #브라우저 식별 정보 = 우리가 정상적인 웹사이트 방문자임을 알려주는 문장
options.add_argument("--lang=ko_KR") #접속 및 방문하는 브라우저의 기본 세팅 언어
options.add_argument("--no-sandbox") #규제 적용 방지

URL = "https://display.wconcept.co.kr/rn/women"

driver = webdriver.Chrome(service=service, options=options) #()안에 매개변수가 들어가야 함
driver.get(URL)

time.sleep(3)

driver.quit() # 특정 사이트 데이터 수집 후, 가상 브라우저 실행 종료 (*메모리 누수를 방지하기 위함)
print("Wconcept 방문 성공👌")
# Out:
# Wconcept 방문 성공👌

# %%
from selenium import webdriver #webdriver가 사람 대신 크롤러의 역할을 함
from selenium.webdriver.common.by import By # 크롤러가 어떤 방식으로 값을 찾아오게 할 것인지 결정
from selenium.webdriver.chrome.service import Service #Service는 크롤러에게 로컬 컴퓨터 내 크롬브라우저 드라이브를 일치할 수 있게끔 해주며, 설치를 해 줌
from selenium.webdriver.chrome.options import Options #크롤러가 어떤 환경에서 어떤 방식으로 크롤링 하도록 할지 옵션을 설정
from webdriver_manager.chrome import ChromeDriverManager #실제 드라이브 설치 역할을 함
import time # 특정 사이트 접속 후, 스크립트 기반의 코드를 서버로부터 가져올 때까지 시간을 벌어주는 역할

service = Service(ChromeDriverManager().install()) #실행은 얘가 함
options = Options()

# options.add_argument("--headless") #가상브라우저를 현재 내 로컬컴퓨터에 나타나지 않도록 할 때
# options.add_argument("--disable-gpu") #가상브라우저를 사용하지 않기 때문에 굳이 gpu 메모리를 사용하지 않겠다는 의미
options.add_argument("--disable-dev-shm-usage") #큰 데이터의 크롤링 시, 데이터를 개발자도구 내 임시 메모리 공간을 사용하지 X (로컬의 공간을 바로 사용하겠다)
options.add_argument("--window-size=1920, 1080") #크롤러의 웹 브라우저 사이즈를 세팅
options.add_argument("--start-maximized") #주변 환경요소와 무관하게 브라우저 사이즈를 무조건 크게
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/152.0.0.0 Safari/537.36") #브라우저 식별 정보 = 우리가 정상적인 웹사이트 방문자임을 알려주는 문장
options.add_argument("--lang=ko_KR") #접속 및 방문하는 브라우저의 기본 세팅 언어
options.add_argument("--no-sandbox") #규제 적용 방지

URL = "https://display.wconcept.co.kr/rn/women"

driver = webdriver.Chrome(service=service, options=options) #()안에 매개변수가 들어가야 함
driver.get(URL)

time.sleep(3)

# best_button = driver.find_element(By.CSS_SELECTOR, "span.mnbrtm-inner") #찾아올 "클래스.값" 
# -> 단, 클래스는 하나의 문서에서 여러번 쓰일 수 있기 때문에 아래 XPATH로 찾아오는 것이 더 정확해!
best_button = driver.find_element(By.XPATH, "//span[text()='베스트']")
# XPATH 사용시 반드시 클래스명 앞에 // 사용 해야 함. 따옴표 사용도 필수임
best_button.click()
time.sleep(3)


driver.quit() # 특정 사이트 데이터 수집 후, 가상 브라우저 실행 종료 (*메모리 누수를 방지하기 위함)
print("Wconcept 방문 성공👌")
# Out:
# Wconcept 방문 성공👌

# %%
dir(driver) # 특정(ex. driver)객체가 사용할 수 있는 매서드를 확인하고 싶을 때 dir(객체명)
# Out:
# ['__abstractmethods__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_authenticator_id',
#  '_bidi_session',
#  '_browser',
#  '_browsing_context',
#  '_check_if_window_handle_is_current',
#  '_devtools',
#  '_emulation',
#  '_fedcm',
#  '_file_detector',
#  '_get_cdp_details',
#  '_input',
#  '_is_remote',
#  '_mobile',
#  '_network',
#  '_permissions',
#  '_request',
#  '_require_fedcm_support',
#  '_script',
#  '_session',
#  '_shadowroot_cls',
#  '_start_bidi',
#  '_storage',
# ...

# %%
# !pip install selenium

# %%
from selenium import webdriver #webdriver가 사람 대신 크롤러의 역할을 함
from selenium.webdriver.common.by import By # 크롤러가 어떤 방식으로 값을 찾아오게 할 것인지 결정
from selenium.webdriver.chrome.service import Service #Service는 크롤러에게 로컬 컴퓨터 내 크롬브라우저 드라이브를 일치할 수 있게끔 해주며, 설치를 해 줌
from selenium.webdriver.chrome.options import Options #크롤러가 어떤 환경에서 어떤 방식으로 크롤링 하도록 할지 옵션을 설정
from webdriver_manager.chrome import ChromeDriverManager #실제 드라이브 설치 역할을 함
import time # 특정 사이트 접속 후, 스크립트 기반의 코드를 서버로부터 가져올 때까지 시간을 벌어주는 역할
import re # regular expression -> 정규표현식 사용시 필요함

service = Service(ChromeDriverManager().install()) #실행은 얘가 함
options = Options()

# options.add_argument("--headless") #가상브라우저를 현재 내 로컬컴퓨터에 나타나지 않도록 할 때
# options.add_argument("--disable-gpu") #가상브라우저를 사용하지 않기 때문에 굳이 gpu 메모리를 사용하지 않겠다는 의미
options.add_argument("--disable-dev-shm-usage") #큰 데이터의 크롤링 시, 데이터를 개발자도구 내 임시 메모리 공간을 사용하지 X (로컬의 공간을 바로 사용하겠다)
options.add_argument("--window-size=1920, 1080") #크롤러의 웹 브라우저 사이즈를 세팅
options.add_argument("--start-maximized") #주변 환경요소와 무관하게 브라우저 사이즈를 무조건 크게
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/152.0.0.0 Safari/537.36") #브라우저 식별 정보 = 우리가 정상적인 웹사이트 방문자임을 알려주는 문장
options.add_argument("--lang=ko_KR") #접속 및 방문하는 브라우저의 기본 세팅 언어
options.add_argument("--no-sandbox") #규제 적용 방지

URL = "https://display.wconcept.co.kr/rn/women"

driver = webdriver.Chrome(service=service, options=options) #()안에 매개변수가 들어가야 함
driver.get(URL)

time.sleep(3)

# 유틸리티 함수
def to_int(text) :
    num = re.sub(r"[^0-9]","",text) # 대체 매서드 sub() / 가격안에 ,를 빼기 위해서 숫자가 아닌 것들에 대해서는 삭제하고 텍스트로 만들라는 의미
    return int(num) if num else 0

    # 아래 문장을 하나로 나타내면 => 위의 식 return int(num) if num else 0이 되는 것
    # if num : 
    #     return int(num)
    # else :
    #     return 0

# --- 베스트 버튼 클릭 ---
# best_button = driver.find_element(By.CSS_SELECTOR, "span.mnbrtm-inner") #찾아올 "클래스.값" 
# -> 단, 클래스는 하나의 문서에서 여러번 쓰일 수 있기 때문에 아래 XPATH로 찾아오는 것이 더 정확해!
best_button = driver.find_element(By.XPATH, "//span[text()='베스트']")
# XPATH 사용시 반드시 클래스명 앞에 // 사용 해야 함. 따옴표 사용도 필수임
best_button.click()
time.sleep(3)

# --- 상품카드 정보 크롤링 ---
items = driver.find_elements(By.CSS_SELECTOR, "div.product-item.item.type-all")
print(f"찾은 상품 수: {len(items)}개")

# --- 상품별 상세데이터 수집 ---
# 본래 idx는 0부터 찾아오기  때문에, 1부터 찾아오라고 명령 함
for idx, item in enumerate(items, 1) :
    # 상품 랭킹 번호 수집(랭킹은 실시간으로 변동되기 때문에 넘버가 아닌, 랭킹으로 가져와야 함)
    ranking_no = int(item.find_element(By.CSS_SELECTOR, "span.rank").text)

    # 브랜드 이름 수집
    brand_name = item.find_element(By.CSS_SELECTOR, "span.text.title").text.strip()

    # 상품 이름 수집
    product_name = item.find_element(By.CSS_SELECTOR, "span.text.detail").text.strip()
    

    # 판매가격(*소비자가=정가, 할인가, 할인율) 수집
    price_box = item.find_element(By.CSS_SELECTOR, "span.prdc-price")

    ## 소비자가(정가)
    try:
        original_price = to_int(price_box.find_element(By.CSS_SELECTOR, "span.text.customer-price").text)
    except :
        original_price = 0

    ## 할인가
    try:
        sale_price = to_int(price_box.find_element(By.CSS_SELECTOR, "span.text.final-price").text)
    except :
        sale_price = 0
        
    ## 할인율
    try:
        discouont_rate = to_int(price_box.find_element(By.CSS_SELECTOR, "span.text.final-discount").text)
    except :
        discouont_rate = 0

        

    # 평점, 리뷰수, 좋아요수
    stats = item.find_element(By.CSS_SELECTOR, "span.stats")

    ## 평점
    try :
        rating = float(stats.find_element(By.CSS_SELECTOR, "span.review em.score").text)
    except :
        rating = 0.0

    ## 리뷰수
    try :
        review_count = to_int(stats.find_element(By.CSS_SELECTOR, "span.review span.text.cnt").text)
    except :
        review_count = 0

    ## 좋아요 수
    try :
        like_count = to_int(stats.find_element(By.CSS_SELECTOR, "span.like span.text.cnt").text)
    except :
        like_count = 0



    # 상품 썸네일 이미지 url
    img_src = item.find_element(By.CSS_SELECTOR, "span.img img").get_attribute("src")
    
    # 상품 상세페이지 url : ex) https://www.wconcept.co.kr/Product/308577412
    img_src = item.find_element(By.CSS_SELECTOR, "span.img img").get_attribute("src")

    match = re.search(r"/(\d{9})[_.]", img_src)
    # print(rank_no, product_name, match.group(1)) #상품 id값 잘 들어오는지 체크하려고 작성한 문장

    if match :
        product_no = match.group(1)
        product_url = f"https://www.wconcept.co.kr/Product/{product_no}"
    else :
        product_no = None
        product_url = ""


    print(CURRENT_TIMESTAMP, brand_name, product_name, original_price, sale_price, discouont_rate, rating, review_count, like_count, img_src, product_url)

driver.quit() # 특정 사이트 데이터 수집 후, 가상 브라우저 실행 종료 (*메모리 누수를 방지하기 위함)
print("Wconcept 방문 성공👌")
# Out:
# 찾은 상품 수: 200개
# 1 디자인스킨 [9/9-9/10, ] 플레이 테이블 소파(미끄럼틀+계단) (+벨크로덮개&미끄럼방지 패드 증정) 285000 160650 43 4.8 150 624 https://product-image.wconcept.co.kr/productimg/image/img1/12/308577412_SS26100.jpg?RS=412 https://www.wconcept.co.kr/Product/308577412
# 2 하시에 [한정특가] [소라 PICK] TAILORED WOOL DOUBLE JACKET [3COLORS] 219000 153300 30 0.0 0 42 https://product-image.wconcept.co.kr/productimg/image/img1/13/308890313_GG60828.jpg?RS=412 https://www.wconcept.co.kr/Product/308890313
# 3 엽페 [9/9 단 하루!] 오버 스트라이프 티셔츠_네이비 79000 44240 44 5.0 124 7526 https://product-image.wconcept.co.kr/productimg/image/img1/85/308189585_XW99009.jpg?RS=412 https://www.wconcept.co.kr/Product/308189585
# 4 아디다스 [24시간 특가] [IH3992] TOKYO W 139000 58380 58 4.9 13 649 https://product-image.wconcept.co.kr/productimg/image/img1/09/308324709_RO49453.jpg?RS=412 https://www.wconcept.co.kr/Product/308324709
# ...

# %%
dir(items)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']
